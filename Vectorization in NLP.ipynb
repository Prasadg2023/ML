# %% [markdown]
# # Vectorization
# 1) Bag of Words (BOW)
# - how many times each word occured in document
# - it ignore grammer
#
# 2) TF - IDF
# - text data into numerical values by giving important word in a document
# ## TF
# - measures how frequently words appear in a document
# - formula = no.of times term t appears in a document/total no.of term in a document
#
# ## IDF
# - measures how important  words is across all document
# - IDF(t) = log(n/1+ df(t))
